# %%
import numpy as np
import cv2
import os,sys
 
from detect import detect_pent,detect_Rnet

RorO=24 #24 Rnet,这里修改48可以生成 Onet数据集
 
#这里修改48可以生成 Onet数据集
stdsize = RorO

pos_save_dir = "data/" + str(stdsize) + "/positive"
part_save_dir = "data/" + str(stdsize) + "/part"
neg_save_dir = "data/" + str(stdsize) + '/negative'
#这里修改48可以生成 Onet数据集
save_dir = "data/" + str(RorO)

# %%
def IoU(box, boxes):
    """Compute IoU between detect box and gt boxes
 
    Parameters:
    -----------
    box: numpy array , shape (5, ): x1, y1, x2, y2, score
        input box
    boxes: numpy array, shape (n, 4): x1, y1, x2, y2
        input ground truth boxes
 
    Returns:
    --------
    ovr: numpy.array, shape (n, )
        IoU
    """
    # box = (x1, y1, x2, y2)
    box_area = (box[2] - box[0] + 1) * (box[3] - box[1] + 1)
    area = (boxes[:, 2] - boxes[:, 0] + 1) * (boxes[:, 3] - boxes[:, 1] + 1)
 
    # abtain the offset of the interception of union between crop_box and gt_box
    xx1 = np.maximum(box[0], boxes[:, 0])
    yy1 = np.maximum(box[1], boxes[:, 1])
    xx2 = np.minimum(box[2], boxes[:, 2])
    yy2 = np.minimum(box[3], boxes[:, 3])
 
    # compute the width and height of the bounding box
    w = np.maximum(0, xx2 - xx1 + 1)
    h = np.maximum(0, yy2 - yy1 + 1)
 
    inter = w * h
    ovr = inter / (box_area + area - inter)
    return ovr

# %%
def mkr(dr):
    if not os.path.exists(dr):
        os.mkdir(dr)

# %%
def read_annotation(base_dir, label_path):
    '''读取文件的image，box'''
    data = dict()
    images = []
    bboxes = []
    labelfile = open(label_path, 'r')
    while True:
        # 图像地址
        imagepath = labelfile.readline().strip('\n')
        if not imagepath:
            break
        imagepath = base_dir + '/images/' + imagepath
        images.append(imagepath)
        # 人脸数目
        nums = labelfile.readline().strip('\n')
     
        one_image_bboxes = []
        for i in range(int(nums)):
           
            bb_info = labelfile.readline().strip('\n').split(' ')
            #人脸框
            face_box = [float(bb_info[i]) for i in range(4)]
            
            xmin = face_box[0]
            ymin = face_box[1]
            xmax = xmin + face_box[2]
            ymax = ymin + face_box[3]
            
            one_image_bboxes.append([xmin, ymin, xmax, ymax])
           
        bboxes.append(one_image_bboxes)


    data['images'] = images
    data['bboxes'] = bboxes
    return data

# %%
data = read_annotation('data/WIDER_train/','data/wider_face_train_bbx_gt.txt')
annotations = data['bboxes']
imgs = data['images']
#annotations= np.load("labels8.npy")#[:100,4].astype(np.float32)
#imgs=np.load("imgs8.npy")
 
num = len(annotations)
print("%d pics in total" % num)
 
#这里修改48可以生成 Onet数据集
size_i = RorO
# Out:
# 12880 pics in total

# %%
imgs
# Out:
# ['data/WIDER_train//images/0--Parade/0_Parade_marchingband_1_849.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_904.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_marchingband_1_799.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_marchingband_1_117.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_marchingband_1_778.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_343.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_marchingband_1_205.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_106.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_476.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_marchingband_1_12.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_marchingband_1_273.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_marchingband_1_928.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_337.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_marchingband_1_579.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade
jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_marchingband_1_94.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_1019.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_81.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_460.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_819.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_876.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_marchingband_1_753.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_24.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_272.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_52.jpg',
#  'data/WIDER_train//images/0--Parade/0_Parade_Parade_0_140.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_409.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_389.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_288.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_924.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_866.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_164.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_243.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_417.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_105.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_463.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_575.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_438.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_613.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_543.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_657.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_65.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_854.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_701.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_234.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_341.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_203.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_715.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_452.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_171.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_773.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_59.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_464.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_71.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_292.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_75.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_396.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_335.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_795.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_788.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_102.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_174.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_254.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_885.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_420.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_686.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_840.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_384.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_538.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_429.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_289.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_542.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_375.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_707.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_640.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_734.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_607.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_765.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_572.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_682.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_537.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_410.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_642.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_331.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_61.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_485.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_515.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_591.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_520.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_404.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_333.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_145.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_656.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_183.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_165.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_42.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_141.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_627.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_571.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_853.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_730.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_121.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_561.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_267.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_678.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_697.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_859.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_626.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_722.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_587.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_475.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_850.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_671.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_268.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_199.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_610.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_113.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_531.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_518.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_238.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_82.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_46.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_545.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_281.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_306.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_337.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_212.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_705.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_130.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_163.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_621.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_860.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_891.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_639.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_830.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_625.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_740.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_379.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_791.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_666.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_716.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_117.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_679.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_940.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_483.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_374.jpg',
#  'data/WIDER_train//images/1--Handshaking/1_Handshaking_Handshaking_1_764.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_1000.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_175.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_30.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_705.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_616.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_99.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_104.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_829.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_143.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_599.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_785.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_370.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_722.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_723.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_124.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_1015.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_264.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_844.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_905.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_731.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_566.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_839.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_471.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_202.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_150.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_854.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_500.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_35.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_390.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_543.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_116.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_564.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_55.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_726.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_1004.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_345.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_94.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_403.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_559.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_795.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_962.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_22.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_792.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_365.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_304.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_262.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_727.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_893.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_597.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_521.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_743.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_526.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_459.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_251.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_690.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_364.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_1038.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_860.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_426.jpg',
#  'data/WIDER_train//images/10--People_Marching/10_People_Marching_People_Marching_2_876.jpg',
# ...
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_48.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_39.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_317.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_289.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_497.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_965.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_377.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_229.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_700.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_392.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_319.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_284.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_410.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_150.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_566.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_1027.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_471.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_139.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_545.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_184.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_114.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_607.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_531.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_383.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_735.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_5.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_710.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_228.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_216.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_3.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_107.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_683.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_203.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_89.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_500.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_36.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_1.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_245.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_402.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_434.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_346.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_129.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_293.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_509.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_300.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_44.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_1033.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_211.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_553.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_209.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_6.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_307.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_570.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_116.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_288.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_599.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_369.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_443.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_380.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_212.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_256.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_863.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_885.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_77.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_393.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_876.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_105.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_294.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_1016.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_376.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_636.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_415.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_96.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_301.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_785.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_831.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_14.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_925.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_73.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_88.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_285.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_504.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_219.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_386.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_864.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_80.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_582.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_60.jpg',
#  'data/WIDER_train//images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_167.jpg',
    -------
    square bbox
    """
    square_bbox = bbox.copy()
 
    h = bbox[:, 3] - bbox[:, 1] + 1
    w = bbox[:, 2] - bbox[:, 0] + 1
    max_side = np.maximum(h,w)
    square_bbox[:, 0] = bbox[:, 0] + w*0.5 - max_side*0.5
    square_bbox[:, 1] = bbox[:, 1] + h*0.5 - max_side*0.5
    square_bbox[:, 2] = square_bbox[:, 0] + max_side - 1
    square_bbox[:, 3] = square_bbox[:, 1] + max_side - 1
    return square_bbox

# %%
p_idx = 0 # positive
n_idx = 0 # negative
d_idx = 0 # dont care
idx = 0
box_idx = 0

# 生成一系列txt文档用于存储Positive，Negative，Part三类数据的信息
f1 = open(os.path.join(save_dir, 'pos_' + str(stdsize) + '.txt'), 'w')
f2 = open(os.path.join(save_dir, 'neg_' + str(stdsize) + '.txt'), 'w')
f3 = open(os.path.join(save_dir, 'part_' + str(stdsize) + '.txt'), 'w')

#len(annotations) 只需要100张图片
for i in range(100):
    '''
    print(annotations[i])
    boxes = annotations[i][0:8].reshape(-1, 2)
    ix=boxes[:,0].min()
    iy=boxes[:,1].min()
    ax=boxes[:,0].max()
    ay=boxes[:,1].max()
    boxes=np.array([[ix,iy,ax,ay]])
    '''
    
    #my code
    boxes = np.array(annotations[i])
    
    #image = imgs[i].copy()
    
    #my code
    image = cv2.imread(imgs[i]).copy()
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
 
    if size_i == 24:
        bbos, pre_bboxes= detect_pent(image)
    else:
        pen_bbos, pen_pre_bboxes = detect_pent(image) #Pnet
        bbos, pre_bboxes = detect_Rnet(image,pen_pre_bboxes) #Rnet
 
    print("盒子数",len(pre_bboxes))
 
    if len(pre_bboxes) == 0:
        continue
 
 
    pre_bboxes = np.array(pre_bboxes)
    dets = convert_to_square(pre_bboxes)
 
    dets[:, 0:4] = np.round(dets[:, 0:4])
 
    
    #img = imgs[i]
    
    #my code
    img = cv2.imread(imgs[i])

    
    idx += 1
 
    height,width,channel = img.shape
 
    neg_num = 0
    for box in dets:
 
        x_left,y_top,x_right,y_bottom = box[0:4].astype(int)
        width = x_right - x_left + 1
        height = y_bottom - y_top + 1
        if width < 20 or x_left < 0 or y_top < 0 or x_right > img.shape[1] - 1 or y_bottom > img.shape[0] - 1:
            continue
 
        Iou = IoU(box,boxes)
 
        cropped_im = img[y_top:y_bottom + 1, x_left:x_right + 1, :]
 
        resized_im = cv2.resize(cropped_im, (stdsize, stdsize),
                                interpolation=cv2.INTER_LINEAR)
 
        # if np.max(Iou) < 0.2 and n_idx < 3.0 * p_idx + 1:
        if np.max(Iou) < 0.3 and neg_num < 60:
            save_file = os.path.join(neg_save_dir,"%s.jpg"%n_idx)
            f2.write(str(stdsize)+"/negative/%s"% n_idx + " 0\n")
            cv2.imwrite(save_file,resized_im)
            n_idx += 1
            neg_num += 1
 
        else:
            idx_Iou = np.argmax(Iou)
            assigned_gt = boxes[idx_Iou]
            x1,y1,x2,y2 = assigned_gt
 
            offset_x1 = (x1 - x_left) / float(width)
            offset_y1 = (y1 - y_top) / float(height)
            offset_x2 = (x2 - x_right) / float(width)
            offset_y2 = (y2 - y_bottom) / float(height)
            if np.max(Iou) >= 0.65:
                save_file = os.path.join(pos_save_dir, "%s.jpg" % p_idx)
                f1.write(str(stdsize)+"/positive/%s"%p_idx + ' 1 %.2f %.2f %.2f %.2f\n' % (
                    offset_x1, offset_y1, offset_x2, offset_y2))
                cv2.imwrite(save_file, resized_im)
                p_idx += 1
 
            elif np.max(Iou) >= 0.4 and d_idx < 1.0 * p_idx + 1:
                save_file = os.path.join(part_save_dir, "%s.jpg" % d_idx)
                f3.write(str(stdsize)+"/part/%s"%d_idx + ' -1 %.2f %.2f %.2f %.2f\n' % (
                    offset_x1, offset_y1, offset_x2, offset_y2))
                cv2.imwrite(save_file, resized_im)
                d_idx += 1
 
    print("%s images done, pos: %s part: %s neg: %s" % (idx, p_idx, d_idx, n_idx))
 
 
f1.close()
f2.close()
f3.close()
# Out:
# 盒子数 2979
# 1 images done, pos: 0 part: 0 neg: 60
# 盒子数 3297
# 2 images done, pos: 0 part: 1 neg: 120
# 盒子数 2391
# 3 images done, pos: 4 part: 5 neg: 180
# 盒子数 5245
# 4 images done, pos: 5 part: 5 neg: 240
# 盒子数 4595
# 5 images done, pos: 10 part: 11 neg: 300
# 盒子数 4413
# 6 images done, pos: 12 part: 13 neg: 360
# 盒子数 3853
# 7 images done, pos: 38 part: 39 neg: 420
# 盒子数 3942
# 8 images done, pos: 46 part: 46 neg: 480
# 盒子数 3584
# 9 images done, pos: 51 part: 52 neg: 540
# 盒子数 5123
# 10 images done, pos: 61 part: 62 neg: 600
# 盒子数 2083
# 11 images done, pos: 63 part: 64 neg: 660
# 盒子数 2504
# 12 images done, pos: 63 part: 64 neg: 720
# 盒子数 2872
# 13 images done, pos: 72 part: 73 neg: 780
# 盒子数 3102
# 14 images done, pos: 72 part: 73 neg: 840
# 盒子数 4260
# 15 images done, pos: 74 part: 75 neg: 900
# 盒子数 1401
# 16 images done, pos: 75 part: 76 neg: 960
# 盒子数 2925
# 17 images done, pos: 77 part: 78 neg: 1020
# 盒子数 2667
# 18 images done, pos: 83 part: 84 neg: 1080
# 盒子数 3939
# 19 images done, pos: 86 part: 87 neg: 1140
# 盒子数 4231
# 20 images done, pos: 87 part: 88 neg: 1200
# 盒子数 467
# 21 images done, pos: 87 part: 88 neg: 1260
# 盒子数 3495
# 22 images done, pos: 87 part: 88 neg: 1320
# 盒子数 4969
# 23 images done, pos: 94 part: 95 neg: 1380
# 盒子数 7123
# 24 images done, pos: 95 part: 96 neg: 1440
# 盒子数 543
# 25 images done, pos: 95 part: 96 neg: 1500
# 盒子数 4324
# 26 images done, pos: 101 part: 102 neg: 1560
# 盒子数 4531
# 27 images done, pos: 112 part: 113 neg: 1620
# 盒子数 3125
# 28 images done, pos: 113 part: 114 neg: 1680
# 盒子数 2746
# 29 images done, pos: 113 part: 114 neg: 1740
# 盒子数 1973
# 30 images done, pos: 114 part: 115 neg: 1800
# 盒子数 4363
# 31 images done, pos: 124 part: 125 neg: 1860
# 盒子数 4068
# 32 images done, pos: 126 part: 127 neg: 1920
# 盒子数 4065
# 33 images done, pos: 139 part: 140 neg: 1980
# 盒子数 1666
# 34 images done, pos: 141 part: 141 neg: 2040
# 盒子数 7268
# 35 images done, pos: 141 part: 141 neg: 2100
# 盒子数 1267
# 36 images done, pos: 141 part: 142 neg: 2160
# 盒子数 601
# 37 images done, pos: 141 part: 142 neg: 2220
# 盒子数 3466
# 38 images done, pos: 141 part: 142 neg: 2280
# 盒子数 3241
# 39 images done, pos: 159 part: 160 neg: 2340
# 盒子数 2742
# 40 images done, pos: 161 part: 162 neg: 2400
# 盒子数 2819
# 41 images done, pos: 168 part: 168 neg: 2460
# 盒子数 3723
# 42 images done, pos: 175 part: 175 neg: 2520
# 盒子数 6264
# 43 images done, pos: 176 part: 176 neg: 2580
# 盒子数 2248
# 44 images done, pos: 177 part: 177 neg: 2640
# 盒子数 3770
# 45 images done, pos: 182 part: 183 neg: 2700
# 盒子数 1634
# 46 images done, pos: 182 part: 183 neg: 2760
# 盒子数 2514
# 47 images done, pos: 182 part: 183 neg: 2820
# 盒子数 4061
# 48 images done, pos: 182 part: 183 neg: 2880
# 盒子数 2335
# 49 images done, pos: 185 part: 184 neg: 2940
# 盒子数 3252
# 50 images done, pos: 188 part: 189 neg: 3000
# 盒子数 3356
# 51 images done, pos: 193 part: 194 neg: 3060
# 盒子数 1297
# 52 images done, pos: 195 part: 196 neg: 3120
# 盒子数 3969
# 53 images done, pos: 195 part: 196 neg: 3180
# 盒子数 4705
# 54 images done, pos: 199 part: 200 neg: 3240
# 盒子数 3878
# 55 images done, pos: 203 part: 204 neg: 3300
# 盒子数 1721
# 56 images done, pos: 205 part: 206 neg: 3360
# 盒子数 3054
# 57 images done, pos: 208 part: 209 neg: 3420
# 盒子数 1362
# 58 images done, pos: 208 part: 209 neg: 3480
# WARNING:tensorflow:5 out of the last 19 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f09fab2a620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f09fab2a620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f09fab2a620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 盒子数 3246
# 59 images done, pos: 210 part: 211 neg: 3540
# 盒子数 8085
# 60 images done, pos: 210 part: 211 neg: 3600
# 盒子数 4286
# 61 images done, pos: 211 part: 212 neg: 3660
# 盒子数 2643
# 62 images done, pos: 213 part: 214 neg: 3720
# 盒子数 3398
# 63 images done, pos: 216 part: 217 neg: 3780
# 盒子数 5111
# 64 images done, pos: 217 part: 218 neg: 3840
# 盒子数 6083
# 65 images done, pos: 222 part: 222 neg: 3900
# 盒子数 4523
# 66 images done, pos: 222 part: 222 neg: 3960
# 盒子数 3364
# 67 images done, pos: 222 part: 223 neg: 4020
# 盒子数 1957
# 68 images done, pos: 223 part: 224 neg: 4080
# WARNING:tensorflow:5 out of the last 19 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f09fb5547b8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f09fb5547b8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f09fb5547b8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 盒子数 3146
# 69 images done, pos: 247 part: 248 neg: 4140
# 盒子数 4585
# 70 images done, pos: 247 part: 248 neg: 4200
# 盒子数 3269
# 71 images done, pos: 249 part: 250 neg: 4260
# 盒子数 3125
# 72 images done, pos: 257 part: 258 neg: 4320
# 盒子数 1562
# 73 images done, pos: 261 part: 262 neg: 4380
# 盒子数 3826
# 74 images done, pos: 268 part: 268 neg: 4440
# 盒子数 1590
# 75 images done, pos: 269 part: 270 neg: 4500
# 盒子数 4082
# 76 images done, pos: 274 part: 275 neg: 4560
# 盒子数 2435
# 77 images done, pos: 280 part: 279 neg: 4620
# 盒子数 3337
# 78 images done, pos: 280 part: 279 neg: 4680
# 盒子数 3883
# 79 images done, pos: 291 part: 292 neg: 4740
# 盒子数 3344
# 80 images done, pos: 292 part: 293 neg: 4800
# 盒子数 3549
# 81 images done, pos: 296 part: 297 neg: 4860
# 盒子数 2196
# 82 images done, pos: 297 part: 298 neg: 4920
# 盒子数 4798
# 83 images done, pos: 299 part: 300 neg: 4980
# 盒子数 3239
# 84 images done, pos: 309 part: 310 neg: 5040
# 盒子数 2495
# 85 images done, pos: 310 part: 311 neg: 5100
# 盒子数 3039
# 86 images done, pos: 325 part: 326 neg: 5160
# 盒子数 2816
# 87 images done, pos: 327 part: 328 neg: 5220
# 盒子数 5096
# 88 images done, pos: 328 part: 328 neg: 5280
# 盒子数 4314
# 89 images done, pos: 328 part: 328 neg: 5340
# 盒子数 1732
# 90 images done, pos: 331 part: 332 neg: 5400
# 盒子数 4663
# 91 images done, pos: 371 part: 372 neg: 5460
# 盒子数 2127
# 92 images done, pos: 391 part: 392 neg: 5520
# 盒子数 3838
# 93 images done, pos: 391 part: 392 neg: 5580
# 盒子数 5135
# 94 images done, pos: 394 part: 395 neg: 5640
# 盒子数 3183
# 95 images done, pos: 403 part: 404 neg: 5700
# 盒子数 2484
# 96 images done, pos: 410 part: 410 neg: 5760
# 盒子数 1679
# 97 images done, pos: 420 part: 420 neg: 5820
# 盒子数 2884
# 98 images done, pos: 421 part: 422 neg: 5880
# 盒子数 2113
# 99 images done, pos: 423 part: 422 neg: 5940
# 盒子数 5170
# 100 images done, pos: 426 part: 427 neg: 6000

# %%
save_dir = "data/24"
size = 24
if not os.path.exists(save_dir):
    os.mkdir(save_dir)
f1 = open(os.path.join(save_dir, 'pos_%s.txt'%(size)), 'r')
f2 = open(os.path.join(save_dir, 'neg_%s.txt'%(size)), 'r')
f3 = open(os.path.join(save_dir, 'part_%s.txt'%(size)), 'r')
 
pos = f1.readlines()
neg = f2.readlines()
part = f3.readlines()
f = open(os.path.join(save_dir, 'label-train%s.txt'%(size)), 'w')
 
for i in range(int(len(pos))):
    p = pos[i].find(" ") + 1
    pos[i] = pos[i][:p-1] + ".jpg " + pos[i][p:-1] + "\n"
    f.write(pos[i])
 
for i in range(int(len(neg))):
    p = neg[i].find(" ") + 1
    neg[i] = neg[i][:p-1] + ".jpg " + neg[i][p:-1] + " -1 -1 -1 -1\n"
    f.write(neg[i])
 
for i in range(int(len(part))):
    p = part[i].find(" ") + 1
    part[i] = part[i][:p-1] + ".jpg " + part[i][p:-1] + "\n"
    f.write(part[i])

f1.close()
f2.close()
f3.close()
