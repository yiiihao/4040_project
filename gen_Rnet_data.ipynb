# %%
import numpy as np
import cv2
import os,sys
 
from detect import detect_pent,detect_Rnet

RorO=24 #24 Rnet,这里修改48可以生成 Onet数据集
 
#这里修改48可以生成 Onet数据集
stdsize = RorO

pos_save_dir = "data/" + str(stdsize) + "/positive"
part_save_dir = "data/" + str(stdsize) + "/part"
neg_save_dir = "data/" + str(stdsize) + '/negative'
#这里修改48可以生成 Onet数据集
save_dir = "data/" + str(RorO)

# %%
def IoU(box, boxes):
    """Compute IoU between detect box and gt boxes
 
    Parameters:
    -----------
    box: numpy array , shape (5, ): x1, y1, x2, y2, score
        input box
    boxes: numpy array, shape (n, 4): x1, y1, x2, y2
        input ground truth boxes
 
    Returns:
    --------
    ovr: numpy.array, shape (n, )
        IoU
    """
    # box = (x1, y1, x2, y2)
    box_area = (box[2] - box[0] + 1) * (box[3] - box[1] + 1)
    area = (boxes[:, 2] - boxes[:, 0] + 1) * (boxes[:, 3] - boxes[:, 1] + 1)
 
    # abtain the offset of the interception of union between crop_box and gt_box
    xx1 = np.maximum(box[0], boxes[:, 0])
    yy1 = np.maximum(box[1], boxes[:, 1])
    xx2 = np.minimum(box[2], boxes[:, 2])
    yy2 = np.minimum(box[3], boxes[:, 3])
 
    # compute the width and height of the bounding box
    w = np.maximum(0, xx2 - xx1 + 1)
    h = np.maximum(0, yy2 - yy1 + 1)
 
    inter = w * h
    ovr = inter / (box_area + area - inter)
    return ovr

# %%
def mkr(dr):
    if not os.path.exists(dr):
        os.mkdir(dr)

# %%
def read_annotation(base_dir, label_path):
    '''读取文件的image，box'''
    data = dict()
    images = []
    bboxes = []
    labelfile = open(label_path, 'r')
    while True:
        # 图像地址
        imagepath = labelfile.readline().strip('\n')
        if not imagepath:
            break
        imagepath = base_dir + '/images/' + imagepath
        images.append(imagepath)
        # 人脸数目
        nums = labelfile.readline().strip('\n')
     
        one_image_bboxes = []
        for i in range(int(nums)):
           
            bb_info = labelfile.readline().strip('\n').split(' ')
            #人脸框
            face_box = [float(bb_info[i]) for i in range(4)]
            
            xmin = face_box[0]
            ymin = face_box[1]
            xmax = xmin + face_box[2]
            ymax = ymin + face_box[3]
            
            one_image_bboxes.append([xmin, ymin, xmax, ymax])
           
        bboxes.append(one_image_bboxes)


    data['images'] = images
    data['bboxes'] = bboxes
    return data

# %%
data = read_annotation('data/WIDER_train/','data/wider_face_train_bbx_gt.txt')
annotations = data['bboxes']
imgs = data['images']
#annotations= np.load("labels8.npy")#[:100,4].astype(np.float32)
#imgs=np.load("imgs8.npy")
 
num = len(annotations)
print("%d pics in total" % num)
 
#这里修改48可以生成 Onet数据集
size_i = RorO
# Out:
# 12880 pics in total

# %%
mkr(save_dir)
mkr(pos_save_dir)
mkr(part_save_dir)
mkr(neg_save_dir)

# %%
def convert_to_square(bbox):
    """Convert bbox to square
 
    Parameters:
    ----------
    bbox: numpy array , shape n x 5
        input bbox
 
    Returns:
    -------
    square bbox
    """
    square_bbox = bbox.copy()
 
    h = bbox[:, 3] - bbox[:, 1] + 1
    w = bbox[:, 2] - bbox[:, 0] + 1
    max_side = np.maximum(h,w)
    square_bbox[:, 0] = bbox[:, 0] + w*0.5 - max_side*0.5
    square_bbox[:, 1] = bbox[:, 1] + h*0.5 - max_side*0.5
    square_bbox[:, 2] = square_bbox[:, 0] + max_side - 1
    square_bbox[:, 3] = square_bbox[:, 1] + max_side - 1
    return square_bbox

# %%
p_idx = 0 # positive
n_idx = 0 # negative
d_idx = 0 # dont care
idx = 0
box_idx = 0

# 生成一系列txt文档用于存储Positive，Negative，Part三类数据的信息
f1 = open(os.path.join(save_dir, 'pos_' + str(stdsize) + '.txt'), 'w')
f2 = open(os.path.join(save_dir, 'neg_' + str(stdsize) + '.txt'), 'w')
f3 = open(os.path.join(save_dir, 'part_' + str(stdsize) + '.txt'), 'w')

#len(annotations) 只需要100张图片
for i in range(100):
    '''
    print(annotations[i])
    boxes = annotations[i][0:8].reshape(-1, 2)
    ix=boxes[:,0].min()
    iy=boxes[:,1].min()
    ax=boxes[:,0].max()
    ay=boxes[:,1].max()
    boxes=np.array([[ix,iy,ax,ay]])
    '''
    
    #my code
    boxes = np.array(annotations[i])
    
    #image = imgs[i].copy()
    
    #my code
    image = cv2.imread(imgs[i]).copy()
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
 
    if size_i == 24:
        bbos, pre_bboxes = detect_pent(image)
    else:
        pen_bbos, pen_pre_bboxes, _ = detect_pent(image) #Pnet
        bbos, pre_bboxes, _ = detect_Rnet(image,pen_pre_bboxes) #Rnet
 
    print("盒子数",len(pre_bboxes))
 
    if len(pre_bboxes) == 0:
        continue
 
 
    pre_bboxes = np.array(pre_bboxes)
    dets = convert_to_square(pre_bboxes)
 
    dets[:, 0:4] = np.round(dets[:, 0:4])
 
    
    #img = imgs[i]
    
    #my code
    img = cv2.imread(imgs[i])

    
    idx += 1
 
    height,width,channel = img.shape
 
    neg_num = 0
    for box in dets:
 
        x_left,y_top,x_right,y_bottom = box[0:4].astype(int)
        width = x_right - x_left + 1
        height = y_bottom - y_top + 1
        if width < 20 or x_left < 0 or y_top < 0 or x_right > img.shape[1] - 1 or y_bottom > img.shape[0] - 1:
            continue
 
        Iou = IoU(box,boxes)
 
        cropped_im = img[y_top:y_bottom + 1, x_left:x_right + 1, :]
 
        resized_im = cv2.resize(cropped_im, (stdsize, stdsize),
                                interpolation=cv2.INTER_LINEAR)
 
        # if np.max(Iou) < 0.2 and n_idx < 3.0 * p_idx + 1:
        if np.max(Iou) < 0.3 and neg_num < 60:
            save_file = os.path.join(neg_save_dir,"%s.jpg"%n_idx)
            f2.write(str(stdsize)+"/negative/%s.jpg"% n_idx + " 0\n")
            cv2.imwrite(save_file,resized_im)
            n_idx += 1
            neg_num += 1
 
        else:
            idx_Iou = np.argmax(Iou)
            assigned_gt = boxes[idx_Iou]
            x1,y1,x2,y2 = assigned_gt
 
            offset_x1 = (x1 - x_left) / float(width)
            offset_y1 = (y1 - y_top) / float(height)
            offset_x2 = (x2 - x_right) / float(width)
            offset_y2 = (y2 - y_bottom) / float(height)
            if np.max(Iou) >= 0.65:
                save_file = os.path.join(pos_save_dir, "%s.jpg" % p_idx)
                f1.write(str(stdsize)+"/positive/%s.jpg"%p_idx + ' 1 %.2f %.2f %.2f %.2f\n' % (
                    offset_x1, offset_y1, offset_x2, offset_y2))
                cv2.imwrite(save_file, resized_im)
                p_idx += 1
 
            elif np.max(Iou) >= 0.4 and d_idx < 1.0 * p_idx + 1:
                save_file = os.path.join(part_save_dir, "%s.jpg" % d_idx)
                f3.write(str(stdsize)+"/part/%s.jpg"%d_idx + ' -1 %.2f %.2f %.2f %.2f\n' % (
                    offset_x1, offset_y1, offset_x2, offset_y2))
                cv2.imwrite(save_file, resized_im)
                d_idx += 1
 
    print("%s images done, pos: %s part: %s neg: %s" % (idx, p_idx, d_idx, n_idx))
 
 
f1.close()
f2.close()
f3.close()
# Out:
# 盒子数 4809
# 1 images done, pos: 0 part: 1 neg: 60
# 盒子数 6650
# 2 images done, pos: 0 part: 1 neg: 120
# 盒子数 3044
# 3 images done, pos: 6 part: 7 neg: 180
# 盒子数 5028
# 4 images done, pos: 7 part: 8 neg: 240
# 盒子数 8019
# 5 images done, pos: 15 part: 16 neg: 300
# 盒子数 5633
# 6 images done, pos: 18 part: 19 neg: 360
# 盒子数 6009
# 7 images done, pos: 51 part: 52 neg: 420
# 盒子数 5277
# 8 images done, pos: 72 part: 73 neg: 480
# 盒子数 5049
# 9 images done, pos: 84 part: 85 neg: 540
# 盒子数 6971
# 10 images done, pos: 95 part: 94 neg: 600
# 盒子数 4794
# 11 images done, pos: 97 part: 98 neg: 660
# 盒子数 3829
# 12 images done, pos: 99 part: 100 neg: 720
# 盒子数 4493
# 13 images done, pos: 114 part: 115 neg: 780
# 盒子数 4428
# 14 images done, pos: 114 part: 115 neg: 840
# 盒子数 6365
# 15 images done, pos: 122 part: 123 neg: 900
# 盒子数 2622
# 16 images done, pos: 134 part: 134 neg: 960
# 盒子数 3699
# 17 images done, pos: 135 part: 136 neg: 1020
# 盒子数 4223
# 18 images done, pos: 137 part: 138 neg: 1080
# 盒子数 5719
# 19 images done, pos: 144 part: 145 neg: 1140
# 盒子数 6677
# 20 images done, pos: 144 part: 145 neg: 1200
# 盒子数 1045
# 21 images done, pos: 144 part: 145 neg: 1260
# 盒子数 4859
# 22 images done, pos: 145 part: 146 neg: 1320
# 盒子数 5707
# 23 images done, pos: 159 part: 160 neg: 1380
# 盒子数 11388
# 24 images done, pos: 161 part: 161 neg: 1440
# 盒子数 1108
# 25 images done, pos: 161 part: 161 neg: 1500
# 盒子数 6007
# 26 images done, pos: 172 part: 173 neg: 1560
# 盒子数 6954
# 27 images done, pos: 211 part: 212 neg: 1620
# 盒子数 4699
# 28 images done, pos: 212 part: 212 neg: 1680
# 盒子数 3266
# 29 images done, pos: 214 part: 214 neg: 1740
# 盒子数 2825
# 30 images done, pos: 215 part: 216 neg: 1800
# 盒子数 6893
# 31 images done, pos: 240 part: 241 neg: 1860
# 盒子数 5554
# 32 images done, pos: 241 part: 242 neg: 1920
# 盒子数 8424
# 33 images done, pos: 255 part: 256 neg: 1980
# 盒子数 3177
# 34 images done, pos: 259 part: 260 neg: 2040
# 盒子数 12360
# 35 images done, pos: 259 part: 260 neg: 2100
# 盒子数 1561
# 36 images done, pos: 261 part: 262 neg: 2160
# 盒子数 883
# 37 images done, pos: 261 part: 262 neg: 2220
# 盒子数 4386
# 38 images done, pos: 262 part: 263 neg: 2280
# 盒子数 4841
# 39 images done, pos: 300 part: 301 neg: 2340
# 盒子数 3881
# 40 images done, pos: 304 part: 305 neg: 2400
# 盒子数 4147
# 41 images done, pos: 316 part: 317 neg: 2460
# 盒子数 5237
# 42 images done, pos: 328 part: 329 neg: 2520
# 盒子数 7724
# 43 images done, pos: 328 part: 329 neg: 2580
# 盒子数 4385
# 44 images done, pos: 329 part: 330 neg: 2640
# 盒子数 6024
# 45 images done, pos: 336 part: 337 neg: 2700
# 盒子数 2489
# 46 images done, pos: 337 part: 338 neg: 2760
# 盒子数 5736
# 47 images done, pos: 337 part: 338 neg: 2820
# 盒子数 6555
# 48 images done, pos: 338 part: 338 neg: 2880
# 盒子数 3959
# 49 images done, pos: 349 part: 350 neg: 2940
# 盒子数 4851
# 50 images done, pos: 367 part: 368 neg: 3000
# 盒子数 4992
# 51 images done, pos: 377 part: 378 neg: 3060
# 盒子数 2581
# 52 images done, pos: 378 part: 379 neg: 3120
# 盒子数 5131
# 53 images done, pos: 378 part: 379 neg: 3180
# 盒子数 7999
# 54 images done, pos: 391 part: 392 neg: 3240
# 盒子数 4909
# 55 images done, pos: 399 part: 400 neg: 3300
# 盒子数 2778
# 56 images done, pos: 407 part: 408 neg: 3360
# 盒子数 4813
# 57 images done, pos: 411 part: 412 neg: 3420
# 盒子数 2121
# 58 images done, pos: 411 part: 412 neg: 3480
# WARNING:tensorflow:5 out of the last 19 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd52cad3d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd52cad3d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd52cad3d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 盒子数 6241
# 59 images done, pos: 417 part: 417 neg: 3540
# 盒子数 11773
# 60 images done, pos: 417 part: 418 neg: 3600
# 盒子数 6382
# 61 images done, pos: 418 part: 419 neg: 3660
# 盒子数 5161
# 62 images done, pos: 428 part: 429 neg: 3720
# 盒子数 6055
# 63 images done, pos: 433 part: 434 neg: 3780
# 盒子数 7396
# 64 images done, pos: 433 part: 434 neg: 3840
# 盒子数 8621
# 65 images done, pos: 443 part: 441 neg: 3900
# 盒子数 6132
# 66 images done, pos: 443 part: 441 neg: 3960
# 盒子数 4613
# 67 images done, pos: 445 part: 446 neg: 4020
# 盒子数 2612
# 68 images done, pos: 445 part: 446 neg: 4080
# WARNING:tensorflow:5 out of the last 19 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd52f14ab90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd52f14ab90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd52f14ab90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 盒子数 5143
# 69 images done, pos: 501 part: 502 neg: 4140
# 盒子数 11887
# 70 images done, pos: 501 part: 502 neg: 4200
# 盒子数 4916
# 71 images done, pos: 504 part: 505 neg: 4260
# 盒子数 4204
# 72 images done, pos: 518 part: 518 neg: 4320
# 盒子数 3010
# 73 images done, pos: 529 part: 530 neg: 4380
# 盒子数 5679
# 74 images done, pos: 548 part: 549 neg: 4440
# 盒子数 2765
# 75 images done, pos: 552 part: 553 neg: 4500
# 盒子数 5848
# 76 images done, pos: 562 part: 563 neg: 4560
# 盒子数 4783
# 77 images done, pos: 573 part: 574 neg: 4620
# 盒子数 4335
# 78 images done, pos: 573 part: 574 neg: 4680
# 盒子数 7366
# 79 images done, pos: 585 part: 586 neg: 4740
# 盒子数 5320
# 80 images done, pos: 592 part: 593 neg: 4800
# 盒子数 6111
# 81 images done, pos: 602 part: 603 neg: 4860
# 盒子数 4077
# 82 images done, pos: 602 part: 603 neg: 4920
# 盒子数 9027
# 83 images done, pos: 606 part: 606 neg: 4980
# 盒子数 4194
# 84 images done, pos: 628 part: 629 neg: 5040
# 盒子数 4734
# 85 images done, pos: 630 part: 631 neg: 5100
# 盒子数 4608
# 86 images done, pos: 654 part: 655 neg: 5160
# 盒子数 4442
# 87 images done, pos: 656 part: 657 neg: 5220
# 盒子数 8540
# 88 images done, pos: 656 part: 657 neg: 5280
# 盒子数 6808
# 89 images done, pos: 656 part: 657 neg: 5340
# 盒子数 2593
# 90 images done, pos: 658 part: 659 neg: 5400
# 盒子数 6828
# 91 images done, pos: 708 part: 709 neg: 5460
# 盒子数 3390
# 92 images done, pos: 740 part: 741 neg: 5520
# 盒子数 5141
# 93 images done, pos: 740 part: 741 neg: 5580
# 盒子数 7318
# 94 images done, pos: 750 part: 751 neg: 5640
# 盒子数 5762
# 95 images done, pos: 768 part: 769 neg: 5700
# 盒子数 4078
# 96 images done, pos: 782 part: 783 neg: 5760
# 盒子数 3004
# 97 images done, pos: 793 part: 794 neg: 5820
# 盒子数 5582
# 98 images done, pos: 798 part: 799 neg: 5880
# 盒子数 3275
# 99 images done, pos: 798 part: 799 neg: 5940
# 盒子数 6320
# 100 images done, pos: 802 part: 802 neg: 6000

# %%
save_dir = "data/24"
size = 24
if not os.path.exists(save_dir):
    os.mkdir(save_dir)
f1 = open(os.path.join(save_dir, 'pos_%s.txt'%(size)), 'r')
f2 = open(os.path.join(save_dir, 'neg_%s.txt'%(size)), 'r')
f3 = open(os.path.join(save_dir, 'part_%s.txt'%(size)), 'r')
 
pos = f1.readlines()
neg = f2.readlines()
part = f3.readlines()
f = open(os.path.join(save_dir, 'label-train%s.txt'%(size)), 'w')
 
for i in range(int(len(pos))):
    p = pos[i].find(" ") + 1
    pos[i] = pos[i][:p-1] + " " + pos[i][p:-1] + "\n"
    f.write(pos[i])

for i in range(int(len(neg))):
    p = neg[i].find(" ") + 1
    neg[i] = neg[i][:p-1] + " " + neg[i][p:-1] + " -1 -1 -1 -1\n"
    f.write(neg[i])

for i in range(int(len(part))):
    p = part[i].find(" ") + 1
    part[i] = part[i][:p-1] + " " + part[i][p:-1] + "\n"
    f.write(part[i])

f1.close()
f2.close()
f3.close()
