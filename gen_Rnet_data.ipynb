# %%
import numpy as np
import cv2
import os,sys
 
from detect import detect_pent,detect_Rnet

RorO=24 #24 Rnet,这里修改48可以生成 Onet数据集
 
#这里修改48可以生成 Onet数据集
stdsize = RorO

pos_save_dir = "data/" + str(stdsize) + "/positive"
part_save_dir = "data/" + str(stdsize) + "/part"
neg_save_dir = "data/" + str(stdsize) + '/negative'
#这里修改48可以生成 Onet数据集
save_dir = "data/" + str(RorO)

# %%
def IoU(box, boxes):
    """Compute IoU between detect box and gt boxes
 
    Parameters:
    -----------
    box: numpy array , shape (5, ): x1, y1, x2, y2, score
        input box
    boxes: numpy array, shape (n, 4): x1, y1, x2, y2
        input ground truth boxes
 
    Returns:
    --------
    ovr: numpy.array, shape (n, )
        IoU
    """
    # box = (x1, y1, x2, y2)
    box_area = (box[2] - box[0] + 1) * (box[3] - box[1] + 1)
    area = (boxes[:, 2] - boxes[:, 0] + 1) * (boxes[:, 3] - boxes[:, 1] + 1)
 
    # abtain the offset of the interception of union between crop_box and gt_box
    xx1 = np.maximum(box[0], boxes[:, 0])
    yy1 = np.maximum(box[1], boxes[:, 1])
    xx2 = np.minimum(box[2], boxes[:, 2])
    yy2 = np.minimum(box[3], boxes[:, 3])
 
    # compute the width and height of the bounding box
    w = np.maximum(0, xx2 - xx1 + 1)
    h = np.maximum(0, yy2 - yy1 + 1)
 
    inter = w * h
    ovr = inter / (box_area + area - inter)
    return ovr

# %%
def mkr(dr):
    if not os.path.exists(dr):
        os.mkdir(dr)

# %%
def read_annotation(base_dir, label_path):
    '''读取文件的image，box'''
    data = dict()
    images = []
    bboxes = []
    labelfile = open(label_path, 'r')
    while True:
        # 图像地址
        imagepath = labelfile.readline().strip('\n')
        if not imagepath:
            break
        imagepath = base_dir + '/images/' + imagepath
        images.append(imagepath)
        # 人脸数目
        nums = labelfile.readline().strip('\n')
     
        one_image_bboxes = []
        for i in range(int(nums)):
           
            bb_info = labelfile.readline().strip('\n').split(' ')
            #人脸框
            face_box = [float(bb_info[i]) for i in range(4)]
            
            xmin = face_box[0]
            ymin = face_box[1]
            xmax = xmin + face_box[2]
            ymax = ymin + face_box[3]
            
            one_image_bboxes.append([xmin, ymin, xmax, ymax])
           
        bboxes.append(one_image_bboxes)


    data['images'] = images
    data['bboxes'] = bboxes
    return data

# %%
data = read_annotation('data/WIDER_train/','data/wider_face_train_bbx_gt.txt')
annotations = data['bboxes']
imgs = data['images']
#annotations= np.load("labels8.npy")#[:100,4].astype(np.float32)
#imgs=np.load("imgs8.npy")
 
num = len(annotations)
print("%d pics in total" % num)
 
#这里修改48可以生成 Onet数据集
size_i = RorO
# Out:
# 12880 pics in total

# %%
mkr(save_dir)
mkr(pos_save_dir)
mkr(part_save_dir)
mkr(neg_save_dir)

# %%
def convert_to_square(bbox):
    """Convert bbox to square
 
    Parameters:
    ----------
    bbox: numpy array , shape n x 5
        input bbox
 
    Returns:
    -------
    square bbox
    """
    square_bbox = bbox.copy()
 
    h = bbox[:, 3] - bbox[:, 1] + 1
    w = bbox[:, 2] - bbox[:, 0] + 1
    max_side = np.maximum(h,w)
    square_bbox[:, 0] = bbox[:, 0] + w*0.5 - max_side*0.5
    square_bbox[:, 1] = bbox[:, 1] + h*0.5 - max_side*0.5
    square_bbox[:, 2] = square_bbox[:, 0] + max_side - 1
    square_bbox[:, 3] = square_bbox[:, 1] + max_side - 1
    return square_bbox

# %%
p_idx = 0 # positive
n_idx = 0 # negative
d_idx = 0 # dont care
idx = 0
box_idx = 0

# 生成一系列txt文档用于存储Positive，Negative，Part三类数据的信息
f1 = open(os.path.join(save_dir, 'pos_' + str(stdsize) + '.txt'), 'w')
f2 = open(os.path.join(save_dir, 'neg_' + str(stdsize) + '.txt'), 'w')
f3 = open(os.path.join(save_dir, 'part_' + str(stdsize) + '.txt'), 'w')

#len(annotations) 只需要100张图片
for i in range(100):
    '''
    print(annotations[i])
    boxes = annotations[i][0:8].reshape(-1, 2)
    ix=boxes[:,0].min()
    iy=boxes[:,1].min()
    ax=boxes[:,0].max()
    ay=boxes[:,1].max()
    boxes=np.array([[ix,iy,ax,ay]])
    '''
    
    #my code
    boxes = np.array(annotations[i])
    
    #image = imgs[i].copy()
    
    #my code
    image = cv2.imread(imgs[i]).copy()
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
 
    if size_i == 24:
        bbos, pre_bboxes= detect_pent(image)
    else:
        pen_bbos, pen_pre_bboxes = detect_pent(image) #Pnet
        bbos, pre_bboxes = detect_Rnet(image,pen_pre_bboxes) #Rnet
 
    print("盒子数",len(pre_bboxes))
 
    if len(pre_bboxes) == 0:
        continue
 
 
    pre_bboxes = np.array(pre_bboxes)
    dets = convert_to_square(pre_bboxes)
 
    dets[:, 0:4] = np.round(dets[:, 0:4])
 
    
    #img = imgs[i]
    
    #my code
    img = cv2.imread(imgs[i])

    
    idx += 1
 
    height,width,channel = img.shape
 
    neg_num = 0
    for box in dets:
 
        x_left,y_top,x_right,y_bottom = box[0:4].astype(int)
        width = x_right - x_left + 1
        height = y_bottom - y_top + 1
        if width < 20 or x_left < 0 or y_top < 0 or x_right > img.shape[1] - 1 or y_bottom > img.shape[0] - 1:
            continue
 
        Iou = IoU(box,boxes)
 
        cropped_im = img[y_top:y_bottom + 1, x_left:x_right + 1, :]
 
        resized_im = cv2.resize(cropped_im, (stdsize, stdsize),
                                interpolation=cv2.INTER_LINEAR)
 
        # if np.max(Iou) < 0.2 and n_idx < 3.0 * p_idx + 1:
        if np.max(Iou) < 0.3 and neg_num < 60:
            save_file = os.path.join(neg_save_dir,"%s.jpg"%n_idx)
            f2.write(str(stdsize)+"/negative/%s"% n_idx + " 0\n")
            cv2.imwrite(save_file,resized_im)
            n_idx += 1
            neg_num += 1
 
        else:
            idx_Iou = np.argmax(Iou)
            assigned_gt = boxes[idx_Iou]
            x1,y1,x2,y2 = assigned_gt
 
            offset_x1 = (x1 - x_left) / float(width)
            offset_y1 = (y1 - y_top) / float(height)
            offset_x2 = (x2 - x_right) / float(width)
            offset_y2 = (y2 - y_bottom) / float(height)
            if np.max(Iou) >= 0.65:
                save_file = os.path.join(pos_save_dir, "%s.jpg" % p_idx)
                f1.write(str(stdsize)+"/positive/%s"%p_idx + ' 1 %.2f %.2f %.2f %.2f\n' % (
                    offset_x1, offset_y1, offset_x2, offset_y2))
                cv2.imwrite(save_file, resized_im)
                p_idx += 1
 
            elif np.max(Iou) >= 0.4 and d_idx < 1.0 * p_idx + 1:
                save_file = os.path.join(part_save_dir, "%s.jpg" % d_idx)
                f3.write(str(stdsize)+"/part/%s"%d_idx + ' -1 %.2f %.2f %.2f %.2f\n' % (
                    offset_x1, offset_y1, offset_x2, offset_y2))
                cv2.imwrite(save_file, resized_im)
                d_idx += 1
 
    print("%s images done, pos: %s part: %s neg: %s" % (idx, p_idx, d_idx, n_idx))
 
 
f1.close()
f2.close()
f3.close()
# Out:
# 盒子数 8913
# 1 images done, pos: 0 part: 1 neg: 60
# 盒子数 7362
# 2 images done, pos: 1 part: 1 neg: 120
# 盒子数 3993
# 3 images done, pos: 11 part: 11 neg: 180
# 盒子数 6357
# 4 images done, pos: 12 part: 13 neg: 240
# 盒子数 9276
# 5 images done, pos: 22 part: 23 neg: 300
# 盒子数 7852
# 6 images done, pos: 25 part: 25 neg: 360
# 盒子数 7507
# 7 images done, pos: 72 part: 72 neg: 420
# 盒子数 7008
# 8 images done, pos: 102 part: 103 neg: 480
# 盒子数 6748
# 9 images done, pos: 113 part: 114 neg: 540
# 盒子数 9043
# 10 images done, pos: 125 part: 126 neg: 600
# 盒子数 5578
# 11 images done, pos: 130 part: 131 neg: 660
# 盒子数 5114
# 12 images done, pos: 133 part: 134 neg: 720
# 盒子数 5391
# 13 images done, pos: 148 part: 149 neg: 780
# 盒子数 5135
# 14 images done, pos: 148 part: 149 neg: 840
# 盒子数 7314
# 15 images done, pos: 154 part: 155 neg: 900
# 盒子数 4399
# 16 images done, pos: 163 part: 163 neg: 960
# 盒子数 5234
# 17 images done, pos: 167 part: 168 neg: 1020
# 盒子数 5109
# 18 images done, pos: 174 part: 175 neg: 1080
# 盒子数 6246
# 19 images done, pos: 186 part: 187 neg: 1140
# 盒子数 7914
# 20 images done, pos: 187 part: 188 neg: 1200
# 盒子数 1867
# 21 images done, pos: 187 part: 188 neg: 1260
# 盒子数 6822
# 22 images done, pos: 188 part: 189 neg: 1320
# 盒子数 7987
# 23 images done, pos: 196 part: 197 neg: 1380
# 盒子数 13892
# 24 images done, pos: 200 part: 199 neg: 1440
# 盒子数 1509
# 25 images done, pos: 204 part: 204 neg: 1500
# 盒子数 7495
# 26 images done, pos: 220 part: 221 neg: 1560
# 盒子数 9947
# 27 images done, pos: 269 part: 270 neg: 1620
# 盒子数 5554
# 28 images done, pos: 270 part: 271 neg: 1680
# 盒子数 3897
# 29 images done, pos: 273 part: 274 neg: 1740
# 盒子数 3327
# 30 images done, pos: 275 part: 276 neg: 1800
# 盒子数 7324
# 31 images done, pos: 309 part: 310 neg: 1860
# 盒子数 6958
# 32 images done, pos: 310 part: 311 neg: 1920
# 盒子数 8830
# 33 images done, pos: 328 part: 329 neg: 1980
# 盒子数 3627
# 34 images done, pos: 331 part: 332 neg: 2040
# 盒子数 13156
# 35 images done, pos: 331 part: 332 neg: 2100
# 盒子数 2108
# 36 images done, pos: 332 part: 333 neg: 2160
# 盒子数 1690
# 37 images done, pos: 332 part: 333 neg: 2220
# 盒子数 5395
# 38 images done, pos: 337 part: 338 neg: 2280
# 盒子数 5441
# 39 images done, pos: 389 part: 390 neg: 2340
# 盒子数 5246
# 40 images done, pos: 395 part: 396 neg: 2400
# 盒子数 5313
# 41 images done, pos: 411 part: 412 neg: 2460
# 盒子数 6450
# 42 images done, pos: 427 part: 428 neg: 2520
# 盒子数 14495
# 43 images done, pos: 429 part: 430 neg: 2580
# 盒子数 6494
# 44 images done, pos: 430 part: 431 neg: 2640
# 盒子数 7250
# 45 images done, pos: 438 part: 439 neg: 2700
# 盒子数 3496
# 46 images done, pos: 440 part: 441 neg: 2760
# 盒子数 8508
# 47 images done, pos: 440 part: 441 neg: 2820
# 盒子数 8624
# 48 images done, pos: 441 part: 442 neg: 2880
# 盒子数 5010
# 49 images done, pos: 462 part: 463 neg: 2940
# 盒子数 5921
# 50 images done, pos: 485 part: 486 neg: 3000
# 盒子数 8630
# 51 images done, pos: 494 part: 495 neg: 3060
# 盒子数 3458
# 52 images done, pos: 496 part: 497 neg: 3120
# 盒子数 6527
# 53 images done, pos: 496 part: 497 neg: 3180
# 盒子数 9261
# 54 images done, pos: 504 part: 505 neg: 3240
# 盒子数 7258
# 55 images done, pos: 514 part: 514 neg: 3300
# 盒子数 3117
# 56 images done, pos: 523 part: 524 neg: 3360
# 盒子数 6064
# 57 images done, pos: 528 part: 529 neg: 3420
# 盒子数 2853
# 58 images done, pos: 529 part: 530 neg: 3480
# WARNING:tensorflow:5 out of the last 19 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f924171a7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f924171a7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f924171a7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 盒子数 7153
# 59 images done, pos: 538 part: 539 neg: 3540
# 盒子数 11729
# 60 images done, pos: 538 part: 539 neg: 3600
# 盒子数 16599
# 61 images done, pos: 539 part: 540 neg: 3660
# 盒子数 4944
# 62 images done, pos: 548 part: 549 neg: 3720
# 盒子数 6835
# 63 images done, pos: 559 part: 560 neg: 3780
# 盒子数 8228
# 64 images done, pos: 559 part: 560 neg: 3840
# 盒子数 10046
# 65 images done, pos: 567 part: 568 neg: 3900
# 盒子数 6805
# 66 images done, pos: 567 part: 568 neg: 3960
# 盒子数 6248
# 67 images done, pos: 570 part: 571 neg: 4020
# 盒子数 3209
# 68 images done, pos: 572 part: 573 neg: 4080
# WARNING:tensorflow:5 out of the last 19 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f92449b1cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f92449b1cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f92449b1cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 盒子数 5359
# 69 images done, pos: 641 part: 642 neg: 4140
# 盒子数 11191
# 70 images done, pos: 641 part: 642 neg: 4200
# 盒子数 6048
# 71 images done, pos: 646 part: 646 neg: 4260
# 盒子数 4560
# 72 images done, pos: 654 part: 655 neg: 4320
# 盒子数 3485
# 73 images done, pos: 671 part: 671 neg: 4380
# 盒子数 6525
# 74 images done, pos: 694 part: 695 neg: 4440
# 盒子数 3083
# 75 images done, pos: 696 part: 697 neg: 4500
# 盒子数 9409
# 76 images done, pos: 709 part: 710 neg: 4560
# 盒子数 4514
# 77 images done, pos: 725 part: 726 neg: 4620
# 盒子数 5491
# 78 images done, pos: 725 part: 726 neg: 4680
# 盒子数 7562
# 79 images done, pos: 736 part: 737 neg: 4740
# 盒子数 6192
# 80 images done, pos: 741 part: 742 neg: 4800
# 盒子数 6750
# 81 images done, pos: 746 part: 747 neg: 4860
# 盒子数 4460
# 82 images done, pos: 748 part: 748 neg: 4920
# 盒子数 8921
# 83 images done, pos: 750 part: 751 neg: 4980
# 盒子数 5178
# 84 images done, pos: 779 part: 780 neg: 5040
# 盒子数 5079
# 85 images done, pos: 783 part: 782 neg: 5100
# 盒子数 6171
# 86 images done, pos: 810 part: 810 neg: 5160
# 盒子数 5448
# 87 images done, pos: 814 part: 815 neg: 5220
# 盒子数 12064
# 88 images done, pos: 814 part: 815 neg: 5280
# 盒子数 7386
# 89 images done, pos: 814 part: 815 neg: 5340
# 盒子数 3143
# 90 images done, pos: 816 part: 817 neg: 5400
# 盒子数 8285
# 91 images done, pos: 893 part: 894 neg: 5460
# 盒子数 4018
# 92 images done, pos: 922 part: 923 neg: 5520
# 盒子数 7029
# 93 images done, pos: 922 part: 923 neg: 5580
# 盒子数 8278
# 94 images done, pos: 931 part: 932 neg: 5640
# 盒子数 6299
# 95 images done, pos: 947 part: 948 neg: 5700
# 盒子数 5150
# 96 images done, pos: 959 part: 960 neg: 5760
# 盒子数 4288
# 97 images done, pos: 972 part: 973 neg: 5820
# 盒子数 6246
# 98 images done, pos: 982 part: 983 neg: 5880
# 盒子数 3952
# 99 images done, pos: 983 part: 984 neg: 5940
# 盒子数 7910
# 100 images done, pos: 988 part: 989 neg: 6000

# %%
save_dir = "data/24"
size = 24
if not os.path.exists(save_dir):
    os.mkdir(save_dir)
f1 = open(os.path.join(save_dir, 'pos_%s.txt'%(size)), 'r')
f2 = open(os.path.join(save_dir, 'neg_%s.txt'%(size)), 'r')
f3 = open(os.path.join(save_dir, 'part_%s.txt'%(size)), 'r')
 
pos = f1.readlines()
neg = f2.readlines()
part = f3.readlines()
f = open(os.path.join(save_dir, 'label-train%s.txt'%(size)), 'w')
 
for i in range(int(len(pos))):
    p = pos[i].find(" ") + 1
    pos[i] = pos[i][:p-1] + ".jpg " + pos[i][p:-1] + "\n"
    f.write(pos[i])
 
for i in range(int(len(neg))):
    p = neg[i].find(" ") + 1
    neg[i] = neg[i][:p-1] + ".jpg " + neg[i][p:-1] + " -1 -1 -1 -1\n"
    f.write(neg[i])
 
for i in range(int(len(part))):
    p = part[i].find(" ") + 1
    part[i] = part[i][:p-1] + ".jpg " + part[i][p:-1] + "\n"
    f.write(part[i])

f1.close()
f2.close()
f3.close()
